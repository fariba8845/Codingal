# %% [markdown]
# <a href="https://colab.research.google.com/github/fariba8845/Codingal/blob/main/InheritanceOOP_ACP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class vehicle:
  def __init__(self,seating_capacity,fare):
    self.seating_capacity=seating_capacity
    self.fare=fare

class bus(vehicle):
  def __init__(self,seating_capacity,fare):
    super().__init__(seating_capacity,fare)
  def Fare(self):
    return self.seating_capacity*100
  def total_price(self):
    fare= self.Fare()
    return fare+fare*10/100


Bus=bus(72,100)
print(Bus.total_price())
# Out:
# 7920.0
