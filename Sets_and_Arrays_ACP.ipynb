# %% [markdown]
# <a href="https://colab.research.google.com/github/fariba8845/Codingal/blob/main/Sets_and_Arrays_ACP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set1=  {'blue','green'}
set2= {'red','green'}

print(set1.symmetric_difference(set2))

set3= {1,2,3,4,5}
set4= {1,5,6,7,8,9}

print(set3.symmetric_difference(set4))
# Out:
# {'red', 'blue'}
# {2, 3, 4, 6, 7, 8, 9}
