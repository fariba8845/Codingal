# %% [markdown]
# <a href="https://colab.research.google.com/github/fariba8845/Codingal/blob/main/ExceptionErrorCWS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num= int(input("Enter your number: "))
  print(num)
except ValueError as ex:
  print("Exception: ",ex)


print("I am outside the try block")
# Out:
# Enter your number: 7
# 7
# I am outside the try block

# %%
try:
  num1= int(input("Enter 1st number: "))
  num2= int(input(" Enter 2nd number: "))
  result= num1/num2
  print("Result is: ",result)

except ZeroDivisionError:
  print("Division by zero is not allowed")
except ValueError:
  print("Please enter a numerical value")
except NameError as ex:
  print("The exception is: ", ex)

except:
  print("Something went wrong")
finally:
  print("I shall execute this code no matter what happenes:)")
# Out:
# Enter 1st number: 40
#  Enter 2nd number: 5
# Result is:  8.0
# I shall execute this code no matter what happenes:)

# %%
valid= False

while not valid:
  try:
   n=int(input("Enter any number: "))
   while n%2 == 0:
     print("byeee")
     valid = True
  except ValueError:
    print("Invalid")
# Out:
# Streaming output truncated to the last 5000 lines.
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# byeee
# ...
