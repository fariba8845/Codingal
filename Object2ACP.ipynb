# %% [markdown]
# <a href="https://colab.research.google.com/github/fariba8845/Codingal/blob/main/Object2ACP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class circle:
  def __init__(self,radius):
    self.radius= int(radius)
  def area(self):
    return 3.14*self.radius*self.radius
  def perimeter(self):
    return 2*3.14*self.radius
circ= circle(input("Enter the circle's radius: "))
print("The area of the circle is",circ.area())
print("The perimeter of the circle is",circ.perimeter())
# Out:
# Enter the circle's radius: 6
# The area of the circle is 113.03999999999999
# The perimeter of the circle is 37.68
