# %% [markdown]
# <a href="https://colab.research.google.com/github/fariba8845/Codingal/blob/main/EncapsulationACP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class reverse:
  def __init__(self,s):
    self.s=s
  def reverse_string(self):
    reversed_text= "".join(reversed(self.s))
    return reversed_text

string= reverse(input("Enter a string: "))
print(string.reverse_string())
# Out:
# Enter a string: fariba
# abiraf
